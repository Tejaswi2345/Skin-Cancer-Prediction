# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
# Function to preprocess and prepare an image for prediction
def preprocess_image(image_path):
    img = cv2.imread(image_path)
    img = cv2.resize(img, (224, 224))
    img = img / 255.0  # Normalize the image
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    return img

# %%
# Function to make a prediction on the preprocessed image
def predict_image(image_path, model, labels):
    preprocessed_img = preprocess_image(image_path)
    prediction = model.predict(preprocessed_img)
    class_idx = np.argmax(prediction)
    class_label = labels[class_idx]
    confidence = prediction[0][class_idx]
    return class_label, confidence

# %%
# Load the model and labels
import tensorflow as tf
model = tf.keras.models.load_model('/tmp/saved_models/1691684538')  
labels = ['Benign', 'Malignant']
# Out:
# WARNING:tensorflow:From C:\Users\TEJASWI\desktop\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\TEJASWI\desktop\Lib\site-packages\keras\src\saving\legacy\saved_model\load.py:107: The name tf.gfile.Exists is deprecated. Please use tf.io.gfile.exists instead.
#
# WARNING:tensorflow:From C:\Users\TEJASWI\desktop\Lib\site-packages\keras\src\engine\functional.py:156: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\TEJASWI\desktop\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
# Path to the single test image
single_image_path = '/content/drive/MyDrive/Android-App-Skin-Cancer-Detector/Test/single_image.jpg'  # Replace with your image path

# %%
import cv2
import numpy as np
import tensorflow as tf

def preprocess_image(image_path):
    img = cv2.imread(image_path)
    
    if img is None:
        raise ValueError("Image not loaded properly")
    
    img = cv2.resize(img, (224, 224))
    img = img / 255.0  # Normalize the image
    img = np.expand_dims(img, axis=0)  # Add batch dimension
    return img

def predict_image(image_path, model, labels):
    preprocessed_img = preprocess_image(image_path)
    prediction = model.predict(preprocessed_img)
    class_idx = np.argmax(prediction)
    predicted_class = labels[class_idx]
    confidence = prediction[0][class_idx]
    return predicted_class, confidence

# Load your model and labels
model = tf.keras.models.load_model('/tmp/saved_models/1691684538')  # Replace with your model path
labels = ['Benign', 'Malignant'] 

# Provide the path to your single image
single_image_path = r'C:\Users\TEJASWI\OneDrive\Documents\Deep Learning Projects\Android-App-Skin-Cancer-Detector\Testing\Test\malignant\6.jpg'

# Make a prediction for the single image
predicted_class, confidence = predict_image(single_image_path, model, labels)
print(f"Predicted Class: {predicted_class}, Confidence: {confidence:.4f}")
# Out:
# 1/1 [==============================] - 5s 5s/step
# Predicted Class: Malignant, Confidence: 0.6845

# %%
# Display the image
img = cv2.imread(single_image_path)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title(f"Predicted: {predicted_class}\nConfidence: {confidence:.4f}")
plt.axis('off')
plt.show()
